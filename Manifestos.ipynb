# %%
import numpy as np
import pandas as pd

# %%
bund=pd.read_csv('Data/Results/Bundestagswahlen.csv')
bund
# Out:
#             Partei   1949   1953   1957   1961   1965   1969   1972   1976  \
# 0          CDU/CSU  31,01  45,17  50,19  45,32  47,59  46,09  44,86  48,63
# 1              SPD  29,22  28,84  31,75  36,22  39,28  42,67  45,85  42,56
# 2              FDP  11,92   9,54   7,71  12,77   9,49   5,77   8,36   7,92
# 3        DieGrünen    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4        Die Linke    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5              AFD    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6  Wahlbeteiligung  78,49  85,99  87,77  87,74  86,77  86,67  91,11  90,75
#
#     1980   1983   1987   1990   1994   1998   2002   2005   2009   2013   2017
# 0  44,54  48,79  44,26  43,82  41,43  35,14  38,51  35,17   33,8  41,55  32,93
# 1  42,86  38,18  37,04  33,46  36,39  40,93  38,52  34,25  23,03  25,74  20,51
# 2  10,62   6,95   9,09  11,03   6,92   6,25   7,37   9,83  14,56   4,76  10,75
# ...

# %%
europa=pd.read_csv('Data/Results/Europawahlen.csv')
europa
# Out:
#             Partei  1979  1984  1989  1994  1999  2004  2009  2014  2019
# 0          CDU/CSU  49,2    46  37,7  38,8  48,7  44,5  37,9  35,3  28,9
# 1              SPD  40,8  37,4  37,3  32,2  30,7  21,5  20,8  27,3  15,8
# 2              FDP     6   4,8   5,6   4,1     3   6,1    11   3,4   5,4
# 3       Die Grünen   3,2   8,2   8,4  10,1   6,4  11,9  12,1  10,7  20,5
# 4        Die Linke   NaN   NaN   NaN   4,7   5,8   6,1   7,5   7,4   5,5
# 5              AFD   NaN   NaN   NaN   NaN   NaN   NaN   NaN   7,1    11
# 6  Wahlbeteiligung  65,7  56,8  62,3    60  45,2    43  43,3  48,1  61,4

# %%
test_df=pd.read_csv('Data/Manifestos/Bundestagswahlen/b1949_Linke.csv')
test_df
# Out:
#                                                 text  cmp_code  eu_code
# 0  Einheit, Frieden, Wohlstand Aus dem Wahlprogra...       NaN      NaN

# %%
test_df=pd.read_csv('Data/Manifestos/Bundestagswahlen/b2005_Linke.csv')
test_df
# Out:
#                                                   text  cmp_code  eu_code
# 0       Für eine neue soziale Idee Die Linkspartei.PDS       NaN      NaN
# 1    Eine  andere  Politik  ist  nötig  –  für  soz...       NaN      NaN
# 2    Fünf Millionen Arbeitslose, trotz Ausbildungsp...     305.0      NaN
# 3     Die gesellschaftlichen Verhältnisse sind absurd:     503.0      NaN
# 4    Steigende Dividenden gehen einher mit Massenen...     503.0      NaN
# 5    Die Senkung des Spitzensteuersatzes der Einkom...     503.0      NaN
# 6    Steigende Produktivität der Beschäftigten ermö...     503.0      NaN
# 7    Die Krankenversicherten werden mit Praxisgebüh...     504.0      NaN
# 8    Die Arbeitgeberbeiträge werden einseitig gesen...     503.0      NaN
# 9            Die Hauptverlierer sind die Arbeitslosen.     701.0      NaN
# 10   Rot-Grün hat die Bezugsdauer des Arbeitsloseng...     701.0      NaN
# 11   Nicht „Fordern und Fördern“, sondern „Fordern ...     701.0      NaN
# ...

# %%
' '.join(test_df.text.values)
# Out:
# 'Für eine neue soziale Idee Die Linkspartei.PDS Eine  andere  Politik  ist  nötig  –  für  soziale  und  demokratische  Alternativen Fünf Millionen Arbeitslose, trotz Ausbildungspakt Zehntausende fehlende Lehrstellen, Millionen Menschen in ungesicherten Arbeitsverhältnissen, eine nach wie vor bestehende Kluft zwischen Ost-und Westdeutschland – das ist die Bilanz der Politik von SPD und Grünen. Die gesellschaftlichen Verhältnisse sind absurd: Steigende Dividenden gehen einher mit Massenentlassungen und Steuergeschenken an die Vertreter des großen Kapitals. Die Senkung des Spitzensteuersatzes der Einkommenssteuer geht einher mit zunehmender Verschuldung der öffentlichen Haushalte und Massenarbeitslosigkeit. Steigende Produktivität der Beschäftigten ermöglicht kürzere Arbeitszeiten und steigende Einkommen, doch tatsächlich erleben wir Arbeitszeitverlängerungen, Lohn-und Rentenkürzungen. Die Krankenversicherten werden mit Praxisgebühren, Zuzahlungen und Sonderbeiträgen für Zahnersatz und
# ...

# %%
test_df.iloc[:, 0].values
# Out:
# array(['Für eine neue soziale Idee Die Linkspartei.PDS',
#        'Eine  andere  Politik  ist  nötig  –  für  soziale  und  demokratische  Alternativen',
#        'Fünf Millionen Arbeitslose, trotz Ausbildungspakt Zehntausende fehlende Lehrstellen, Millionen Menschen in ungesicherten Arbeitsverhältnissen, eine nach wie vor bestehende Kluft zwischen Ost-und Westdeutschland – das ist die Bilanz der Politik von SPD und Grünen.',
#        'Die gesellschaftlichen Verhältnisse sind absurd:',
#        'Steigende Dividenden gehen einher mit Massenentlassungen und Steuergeschenken an die Vertreter des großen Kapitals.',
#        'Die Senkung des Spitzensteuersatzes der Einkommenssteuer geht einher mit zunehmender Verschuldung der öffentlichen Haushalte und Massenarbeitslosigkeit.',
#        'Steigende Produktivität der Beschäftigten ermöglicht kürzere Arbeitszeiten und steigende Einkommen, doch tatsächlich erleben wir Arbeitszeitverlängerungen, Lohn-und Rentenkürzungen.',
# ...

# %%
test_df.text.values
# Out:
# array(['Für eine neue soziale Idee Die Linkspartei.PDS',
#        'Eine  andere  Politik  ist  nötig  –  für  soziale  und  demokratische  Alternativen',
#        'Fünf Millionen Arbeitslose, trotz Ausbildungspakt Zehntausende fehlende Lehrstellen, Millionen Menschen in ungesicherten Arbeitsverhältnissen, eine nach wie vor bestehende Kluft zwischen Ost-und Westdeutschland – das ist die Bilanz der Politik von SPD und Grünen.',
#        'Die gesellschaftlichen Verhältnisse sind absurd:',
#        'Steigende Dividenden gehen einher mit Massenentlassungen und Steuergeschenken an die Vertreter des großen Kapitals.',
#        'Die Senkung des Spitzensteuersatzes der Einkommenssteuer geht einher mit zunehmender Verschuldung der öffentlichen Haushalte und Massenarbeitslosigkeit.',
#        'Steigende Produktivität der Beschäftigten ermöglicht kürzere Arbeitszeiten und steigende Einkommen, doch tatsächlich erleben wir Arbeitszeitverlängerungen, Lohn-und Rentenkürzungen.',
# ...
